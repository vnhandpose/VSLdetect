# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YoloV5/input
# Out:
# /content/drive/MyDrive/YoloV5/input

# %% [markdown]
# **Video mode**

# %%
#camera only
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
 
def record_video(filename='video.mp4'):
  js = Javascript("""
    async function recordVideo() {
      // mashes together the advanced_outputs.ipynb function provided by Colab, 
      // a bunch of stuff from Stack overflow, and some sample code from:
      // https://developer.mozilla.org/en-US/docs/Web/API/MediaStream_Recording_API
 
      // Optional frames per second argument.
      const options = { mimeType: "video/webm; codecs=vp9" };
      const div = document.createElement('div');
      const capture = document.createElement('button');
      const stopCapture = document.createElement("button");
      capture.textContent = "Start Recording";
      capture.style.background = "green";
      capture.style.color = "white";
 
      stopCapture.textContent = "Stop Recording";
      stopCapture.style.background = "red";
      stopCapture.style.color = "white";
      div.appendChild(capture);
 
      const video = document.createElement('video');
      const recordingVid = document.createElement("video");
      video.style.display = 'block';
 
      const stream = await navigator.mediaDevices.getUserMedia({video: true});
      // create a media recorder instance, which is an object
      // that will let you record what you stream.
      let recorder = new MediaRecorder(stream, options);
      document.body.appendChild(div);
      div.appendChild(video);
      // Video is a media element.  This line here sets the object which serves
      // as the source of the media associated with the HTMLMediaElement
      // Here, we'll set it equal to the stream.
      video.srcObject = stream;
      // We're inside an async function, so this await will fire off the playing
      // of a video. It returns a Promise which is resolved when playback has 
      // been successfully started. Since this is async, the function will be 
      // paused until this has started playing. 
      await video.play();
 
      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);
      // and now, just wait for the capture button to get clicked in order to
      // start recording
      await new Promise((resolve) => {
        capture.onclick = resolve;
      });
      recorder.start();
      capture.replaceWith(stopCapture);
      // use a promise to tell it to stop recording
      await new Promise((resolve) => stopCapture.onclick = resolve);
      recorder.stop();
 
      let recData = await new Promise((resolve) => recorder.ondataavailable = resolve);
      let arrBuff = await recData.data.arrayBuffer();
      
      // stop the stream and remove the video element
      stream.getVideoTracks()[0].stop();
      div.remove();
 
      let binaryString = "";
      let bytes = new Uint8Array(arrBuff);
      bytes.forEach((byte) => {
        binaryString += String.fromCharCode(byte);
      })
      return btoa(binaryString);
    }
    """)
  try:
    display(js)
    data = eval_js('recordVideo({})')
    binary = b64decode(data)
    with open(filename, "wb") as video_file:
      video_file.write(binary)
    print(
        f"Finished recording video. Saved binary under filename in current working directory: {filename}"
    )
  except Exception as err:
      # In case any exceptions arise
      print(str(err))
  return filename

# %%
# %cd /content/drive/MyDrive/YoloV5/input/
from IPython.display import HTML
from base64 import b64encode
 
video_width = 400
 
video_path = record_video()
video_file = open(video_path, "r+b").read()
 
video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

# %%
# detect simple video
# %cd /content/drive/MyDrive/YoloV5/yolov5/
# !rm -rf /content/drive/MyDrive/YoloV5/yolov5/runs/detect/exp
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/drive/MyDrive/YoloV5/input/video.mp4 
# %cd runs/detect/exp
# Out:
# /content/drive/MyDrive/YoloV5/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/YoloV5/input/video.mp4', update=False, view_img=False, weights=['runs/train/yolov5s_results/weights/best.pt'])
# Using torch 1.7.0+cu101 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7313943 parameters, 0 gradients
# video 1/1 (1/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.188s)
# video 1/1 (2/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.195s)
# video 1/1 (3/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.179s)
# video 1/1 (4/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.184s)
# video 1/1 (5/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Es, 1 Os, Done. (0.174s)
# video 1/1 (6/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.169s)
# video 1/1 (7/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Es, 1 Os, Done. (0.183s)
# video 1/1 (8/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.170s)
# video 1/1 (9/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.174s)
# video 1/1 (10/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.178s)
# video 1/1 (11/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.189s)
# video 1/1 (12/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.175s)
# video 1/1 (13/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.175s)
# video 1/1 (14/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.174s)
# video 1/1 (15/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.177s)
# video 1/1 (16/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.167s)
# video 1/1 (17/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 As, Done. (0.168s)
# video 1/1 (18/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (19/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (20/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.180s)
# video 1/1 (21/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.166s)
# video 1/1 (22/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Ks, Done. (0.171s)
# video 1/1 (23/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.167s)
# video 1/1 (24/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Us, Done. (0.175s)
# video 1/1 (25/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.171s)
# video 1/1 (26/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.176s)
# video 1/1 (27/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.166s)
# video 1/1 (28/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.174s)
# video 1/1 (29/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.177s)
# video 1/1 (30/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.181s)
# video 1/1 (31/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.171s)
# video 1/1 (32/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (33/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.177s)
# video 1/1 (34/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, 1 Us, Done. (0.172s)
# video 1/1 (35/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.177s)
# video 1/1 (36/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.176s)
# video 1/1 (37/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.170s)
# video 1/1 (38/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (39/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.171s)
# video 1/1 (40/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.176s)
# video 1/1 (41/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.169s)
# video 1/1 (42/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, 1 Qs, Done. (0.168s)
# video 1/1 (43/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.166s)
# video 1/1 (44/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.171s)
# video 1/1 (45/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.168s)
# video 1/1 (46/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.187s)
# video 1/1 (47/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.172s)
# video 1/1 (48/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.177s)
# video 1/1 (49/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, 1 Us, Done. (0.171s)
# video 1/1 (50/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.174s)
# video 1/1 (51/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.169s)
# video 1/1 (52/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.180s)
# video 1/1 (53/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Bs, Done. (0.165s)
# video 1/1 (54/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.176s)
# video 1/1 (55/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Xs, Done. (0.167s)
# video 1/1 (56/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Js, Done. (0.170s)
# video 1/1 (57/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.179s)
# video 1/1 (58/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, Done. (0.177s)
# video 1/1 (59/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, 1 Os, Done. (0.191s)
# video 1/1 (60/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, 1 Os, Done. (0.173s)
# video 1/1 (61/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, Done. (0.171s)
# video 1/1 (62/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, Done. (0.174s)
# video 1/1 (63/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, Done. (0.177s)
# video 1/1 (64/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.169s)
# video 1/1 (65/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.178s)
# video 1/1 (66/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, Done. (0.168s)
# video 1/1 (67/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.171s)
# video 1/1 (68/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.175s)
# video 1/1 (69/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.173s)
# video 1/1 (70/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.168s)
# video 1/1 (71/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.170s)
# video 1/1 (72/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.165s)
# video 1/1 (73/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.180s)
# video 1/1 (74/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.183s)
# video 1/1 (75/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.169s)
# video 1/1 (76/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (77/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, 1 Xs, Done. (0.165s)
# video 1/1 (78/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.171s)
# video 1/1 (79/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.173s)
# video 1/1 (80/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.178s)
# video 1/1 (81/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.173s)
# video 1/1 (82/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.173s)
# video 1/1 (83/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.171s)
# video 1/1 (84/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.168s)
# video 1/1 (85/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.180s)
# video 1/1 (86/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, Done. (0.174s)
# video 1/1 (87/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Ps, Done. (0.175s)
# video 1/1 (88/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Ps, Done. (0.170s)
# video 1/1 (89/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Ps, Done. (0.169s)
# video 1/1 (90/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Ps, Done. (0.177s)
# video 1/1 (91/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Ps, Done. (0.188s)
# video 1/1 (92/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, Done. (0.172s)
# video 1/1 (93/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Cs, 1 Xs, Done. (0.177s)
# video 1/1 (94/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.171s)
# video 1/1 (95/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.174s)
# video 1/1 (96/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Rs, 1 Xs, Done. (0.177s)
# video 1/1 (97/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Rs, 1 Xs, Done. (0.172s)
# video 1/1 (98/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Rs, 1 Xs, Done. (0.171s)
# video 1/1 (99/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Xs, Done. (0.166s)
# video 1/1 (100/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, 1 Xs, Done. (0.170s)
# video 1/1 (101/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.167s)
# video 1/1 (102/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.185s)
# video 1/1 (103/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.165s)
# video 1/1 (104/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Js, Done. (0.165s)
# video 1/1 (105/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Js, Done. (0.170s)
# video 1/1 (106/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.167s)
# video 1/1 (107/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.168s)
# video 1/1 (108/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (109/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.170s)
# video 1/1 (110/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.169s)
# video 1/1 (111/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Qs, Done. (0.165s)
# video 1/1 (112/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (113/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.180s)
# video 1/1 (114/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 1 Os, 1 Qs, Done. (0.187s)
# video 1/1 (115/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.170s)
# video 1/1 (116/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.174s)
# video 1/1 (117/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.185s)
# video 1/1 (118/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.177s)
# video 1/1 (119/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.178s)
# video 1/1 (120/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.170s)
# video 1/1 (121/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.172s)
# video 1/1 (122/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.167s)
# video 1/1 (123/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.171s)
# video 1/1 (124/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.177s)
# video 1/1 (125/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.167s)
# video 1/1 (126/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.176s)
# video 1/1 (127/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.174s)
# video 1/1 (128/-9.22337e+18) /content/drive/MyDrive/YoloV5/input/video.mp4: 320x416 Done. (0.176s)
# Results saved to runs/detect/exp
# Done. (23.336s)
# /content/drive/My Drive/YoloV5/yolov5/runs/detect/exp

# %% [markdown]
# **Picture mode**

# %%
#picture only
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
# %cd /content/drive/MyDrive/YoloV5/input/
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# detect simple image 
# %cd /content/drive/MyDrive/YoloV5/yolov5/
# !rm -rf /content/drive/MyDrive/YoloV5/yolov5/runs/detect/exp
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/drive/MyDrive/YoloV5/input/input/photo.jpg

# %%
import glob
from IPython.display import Image, display
 
for imageName in glob.glob('/content/drive/MyDrive/YoloV5/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
